# %%
# !nvidia-smi
# Out:
# Fri Jan  5 15:29:29 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 546.29                 Driver Version: 546.29       CUDA Version: 12.3     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                     TCC/WDDM  | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce RTX 4060 ...  WDDM  | 00000000:01:00.0 Off |                  N/A |
# | N/A   43C    P8               2W / 140W |    121MiB /  8188MiB |      2%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#   Using cached ultralytics-8.0.235-py3-none-any.whl.metadata (35 kB)
# ...
#   Using cached opencv_python-4.9.0.80-cp37-abi3-win_amd64.whl.metadata (20 kB)
# ...
#      ---------------------------------------- 0.0/60.4 kB ? eta -:--:--
#      ------------------- ------------------ 30.7/60.4 kB 660.6 kB/s eta 0:00:01
#      -------------------------------------- 60.4/60.4 kB 796.2 kB/s eta 0:00:00
# ...
#   Using cached tqdm-4.66.1-py3-none-any.whl.metadata (57 kB)
# ...
#   Using cached py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# ...
#   Using cached thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# ...
#   Using cached seaborn-0.13.1-py3-none-any.whl.metadata (5.4 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#      ---------------------------------------- 0.0/160.4 kB ? eta -:--:--
#      ---------------------- ---------------- 92.2/160.4 kB 5.5 MB/s eta 0:00:01
#      -------------------------------------- 160.4/160.4 kB 3.2 MB/s eta 0:00:00
# ...

# %%
# !yolo task=detect mode=train model=yolov8s.pt data="C:/Users/ASUS/yolo/yolo/data.yml" epochs=10 imgsz=224 plots=True
# Out:
# ...
# Ultralytics YOLOv8.0.235 🚀 Python-3.10.13 torch-2.1.2+cpu CPU (12th Gen Intel Core(TM) i7-12700H)
# ...
